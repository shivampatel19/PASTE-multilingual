# %%
import json

# %%
# Opening JSON file
f = open('dev.json')

# %%
# returns JSON object as
# a dictionary
data = json.load(f)

# %%
num = 0
for i in data:
    print(num)
    num = num + 1
    print(i)
    if not i['opinions']:
        print("None")
        
    print('\n\n')
# Out:
# 0
# ...

# %%
a = "Shivam "+" : "
b = "Patel"
c = a+b+" ; "

# %%
c
# Out:
# 'Shivam  : Patel ; '

# %%
file_sent = open('dev.sent', 'w')
file_tup = open('dev.tup', 'w')
for i in data:
    tup=""
    #print(i['opinions'])
    if i['opinions']:
        num = 0
        targ = 0
        lt = 0
        lo = len(i['opinions'])
        #if i['opinions'][0]['Target'][0]:
            
        for j in i['opinions']:
            if j['Target'][0]:
                num = num + 1
                if targ==0:
                    #print(num)
                    #num = num + 1
                    #print(i['text'])
                    file_sent.write(i['text']+'\n')
                    targ = targ + 1
        #print(j)
                if (j['Polarity']=='Positive'):
                    tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS'
                    print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS',end=" " )
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else :
                        tup = tup + tup1
                elif (j['Polarity']=='Negative'):
                    tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG'
                    print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG',end=" " )
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else:
                        tup = tup + tup1
        if not targ == 0:
            file_tup.write(tup +'\n')
    #else:
        #print('None')
        
    print('\n\n')
# Out:
# personnel ; helpful ; POS | personnel ; very friendly ; POS | experience ; really good ; POS | welcome ; very warm ; POS | breakfast buffet ; very nicely assorted ; POS
#
#
# The room ; very small ; NEG
#
#
# Hotel Premiere Classe Orly Rungis ; near the airport ; NEG | Hotel Premiere Classe Orly Rungis ; close to Orly major highways ; NEG | Hotel Premiere Classe Orly Rungis ; noise of passing large vehicles ; NEG
#
#
# a bus stop that goes to the RER station ; there is ; POS
#
#
# Rungis market ; there is ; POS
#
#
# Transfer from the airport to the hotel ; free ; POS
#
#
# Minibus ; goes from the airport to a hotel ; POS
#
#
# Transfer from hotel to airport ; 6 Euro. ; NEG
#
#
# holidays ; Best ; POS
#
#
# Everything ; excellent ; POS
#
#
# the friendliness ; enjoyed ; POS | the time ; enjoyed ; POS
#
#
# food ; Fantastic ; POS | view ; breathtaken ; POS
#
#
# moments ; Great ; POS | music ; Great ; POS |
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
file_sent = open('dev.sent', 'w')
file_tup = open('dev.tup', 'w')
num = 1
for i in data:
    tup=""
    #print(i['opinions'])
    if i['opinions']:
        targ = 0
        lt = 0
        lo = len(i['opinions'])
        #if i['opinions'][0]['Target'][0]:
            
        for j in i['opinions']:
            if j['Target'][0]:
                if targ==0:
                    print(num)
                    num = num + 1
                    print(i['text'])
                    file_sent.write(i['text']+'\n')
                    targ = targ + 1
        #print(j)
                if (j['Polarity']=='Positive'):
                    tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS'
                    print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS',end=" " )
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else :
                        tup = tup + tup1
                if (j['Polarity']=='Negative'):
                    tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG'
                    print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG',end=" " )
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else:
                        tup = tup + tup1
        if not targ == 0:
            file_tup.write(tup +'\n')
    #else:
        #print('None')
        
    print('\n\n')
# Out:
# 1
# very warm welcome at the reception , very friendly and helpful personnel , especially at the bar and during breakfast , a really good experience overall , had a relaxing drink at the bar , visited the cigarrum smokers lounge and had a great start into the day at the very nicely assorted breakfast buffet .
# personnel ; helpful ; POS | personnel ; very friendly ; POS | experience ; really good ; POS | welcome ; very warm ; POS | breakfast buffet ; very nicely assorted ; POS
#
#
# 2
# The room is very small , about 10m2
# The room ; very small ; NEG
#
#
# 3
# Hotel Premiere Classe Orly Rungis is near the airport and close to Orly major highways ( all night heard the noise of passing large vehicles ) .
# Hotel Premiere Classe Orly Rungis ; near the airport ; NEG | Hotel Premiere Classe Orly Rungis ; close to Orly major highways ; NEG | Hotel Premiere Classe Orly Rungis ; noise of passing large vehicles ; NEG
#
#
# 4
# ...

# %%
l1 = ["Hire", "the", "top", "1%", "freelancers"]

l2 = []

if l2:
    print("list is not empty")
else:
    print("list is empty")
# Out:
# list is empty

# %%
l1 = [{ 'a':[[],[]],
        'b':[1],
        'c':[1,2]
      },{}]

# %%
len(l1)
# Out:
# 2

# %%
if l1[0]['a'][0]:
    print('true')
else:
    print('false')
# Out:
# false

# %%
l1 = [{'sent_id': 'opener_en/kaf/hotel/english00064_5fe84dfe3d4af6e6b8ef7b2ca8ac6c8f-6',
  'text': 'See you next year .',
  'opinions': []}]

# %%
for i in l1:
    if i['opinions']:
        print('true')

# %%
l1 = {'sent_id': 'opener_en/kaf/hotel/english00210_f4aa2529a7784fec56fad627916db4b7-8', 
 'text': 'Over 40 Euros for a pizza , burger and two drinks .', 
 'opinions': [{'Source': [[], []], 'Target': [[], []], 
'Polar_expression': [['Over 40 Euros for a pizza , burger and two drinks'], ['0:49']], 
               'Polarity': 'Negative', 'Intensity': 'Standard'}]}

# %%
l1['opinions'][0]
# Out:
# {'Source': [[], []],
#  'Target': [[], []],
#  'Polar_expression': [['Over 40 Euros for a pizza , burger and two drinks'],
#   ['0:49']],
#  'Polarity': 'Negative',
#  'Intensity': 'Standard'}

# %%
l1 = {'sent_id': 'opener_en/kaf/hotel/english00032_30ddf6dff464d0b92c6fbae7019ece91-2', 
 'text': 'very warm welcome at the reception , very friendly and helpful personnel , especially at the bar and during breakfast , a really good experience overall , had a relaxing drink at the bar , visited the cigarrum smokers lounge and had a great start into the day at the very nicely assorted breakfast buffet .', 
 'opinions': [{'Source': [[], []], 'Target': [['personnel'], ['63:72']], 
               'Polar_expression': [['helpful'], ['55:62']], 
               'Polarity': 'Positive', 'Intensity': 'Standard'}, 
              {'Source': [[], []], 'Target': [['personnel'], ['63:72']], 
               'Polar_expression': [['very friendly'], ['37:50']], 
               'Polarity': 'Positive', 'Intensity': 'Strong'}, 
              {'Source': [[], []], 'Target': [['experience'], ['134:144']], 
               'Polar_expression': [['really good'], ['122:133']], 
               'Polarity': 'Positive', 'Intensity': 'Strong'}, 
              {'Source': [[], []], 'Target': [['welcome'], ['10:17']], 
               'Polar_expression': [['very warm'], ['0:9']], 
               'Polarity': 'Positive', 'Intensity': 'Strong'}, 
              {'Source': [[], []], 'Target': [['breakfast buffet'], ['288:304']], 
               'Polar_expression': [['very nicely assorted'], ['267:287']], 
               'Polarity': 'Positive', 'Intensity': 'Strong'}]}

# %%
if l1['opinions']:
    string = l1['text'].split(" ")
    for j in l1['opinions']:
        word = j['Target'][0][0]
        word_list = word.split(" ")
        index = string.index(word_list[0])
        print(word + ' ' + str(index))
# Out:
# personnel 11 19
# personnel 11 19
# experience 24 33
# welcome 2 8
# breakfast buffet 19 34

# %%
if l1['opinions']:
    string = l1['text']
    for j in l1['opinions']:
        length = 0
        word = j['Target'][0][0]
        index = string.find(word)
        for i in range(index):
            if string[i] == " ":
                length = length + 1
        #print(len(word.split()))
        print(word + ' ' + str(length) + ' ' + str(length+len(word.split())-1))
# Out:
# personnel 11 11
# personnel 11 11
# experience 24 24
# welcome 2 2
# breakfast buffet 53 54

# %%
file_sent = open('dev.sent', 'w')
file_tup = open('dev.tup', 'w')
num = 1
for i in data:
    tup=""
    #print(i['opinions'])
    if i['opinions']:
        targ = 0
        lt = 0
        lo = len(i['opinions'])
        string = i['text']
        #if i['opinions'][0]['Target'][0]:
            
        for j in i['opinions']:
            if j['Target'][0]:
                if targ==0:
                    #print(num)
                    #num = num + 1
                    #print(i['text'])
                    file_sent.write(i['text']+'\n')
                    targ = targ + 1
        #print(j)
                if (j['Polarity']=='Positive'):
                    tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS'
                    print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS',end=" " )
                    #print('\n' + str(length) + ' ' + str(length+len(word.split())-1) + ' POS')
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else :
                        tup = tup + tup1
                elif (j['Polarity']=='Negative'):
                    tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG'
                    print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG',end=" " )
                    #print('\n' + str(length) + ' ' + str(length+len(word.split())-1) + ' NEG')
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else:
                        tup = tup + tup1
                        
                #length = 0
                #word = j['Target'][0][0]
                #index = string.find(word)
                #for i in range(index):
                #    if string[i] == " ":
                #        length = length + 1        
                
        if not targ == 0:
            file_tup.write(tup +'\n')
    #else:
        #print('None')
        
    print('\n\n')
# Out:
# personnel ; helpful ; POS | personnel ; very friendly ; POS | experience ; really good ; POS | welcome ; very warm ; POS | breakfast buffet ; very nicely assorted ; POS
#
#
# The room ; very small ; NEG
#
#
# Hotel Premiere Classe Orly Rungis ; near the airport ; NEG | Hotel Premiere Classe Orly Rungis ; close to Orly major highways ; NEG | Hotel Premiere Classe Orly Rungis ; noise of passing large vehicles ; NEG
#
#
# a bus stop that goes to the RER station ; there is ; POS
#
#
# Rungis market ; there is ; POS
#
#
# Transfer from the airport to the hotel ; free ; POS
#
#
# Minibus ; goes from the airport to a hotel ; POS
#
#
# Transfer from hotel to airport ; 6 Euro. ; NEG
#
#
# holidays ; Best ; POS
#
#
# Everything ; excellent ; POS
#
#
# the friendliness ; enjoyed ; POS | the time ; enjoyed ; POS
#
#
# food ; Fantastic ; POS | view ; breathtaken ; POS
#
#
# moments ; Great ; POS | music ; Great ; POS |
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
#file_sent = open('dev.sent', 'w')
#file_tup = open('dev.tup', 'w')
file_pointer = open('dev.pointer', 'w')
for i in data:
    tup=""
    #print(i['opinions'])
    if i['opinions']:
        num = 0
        targ = 0
        lt = 0
        lo = len(i['opinions'])
        string = i['text']
        #if i['opinions'][0]['Target'][0]:
            
        for j in i['opinions']:
            print(j)
            if j['Target'][0]:
                num = num + 1
                if targ==0:
                    #print(num)
                    #num = num + 1
                    #print(i['text'])
                    #file_sent.write(i['text']+'\n')
                    targ = targ + 1
        #print(j)
                length = 0
                word = j['Target'][0][0]
                index = string.find(word)
                for i in range(index):
                    if string[i] == " ":
                        length = length + 1
                
                if (j['Polarity']=='Positive'):
                    tup1 = str(length) + ' ' + str(length+len(word.split())-1) + ' POS'
                    print(str(length) + ' ' + str(length+len(word.split())-1) + ' POS',end=" " )
                    #tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS'
                    #print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS',end=" " )
                    #print('\n' + str(length) + ' ' + str(length+len(word.split())-1) + ' POS')
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else :
                        tup = tup + tup1
                elif (j['Polarity']=='Negative'):
                    tup1 = str(length) + ' ' + str(length+len(word.split())-1) + ' NEG'
                    print(str(length) + ' ' + str(length+len(word.split())-1) + ' NEG',end=" " )
                    #tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG'
                    #print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG',end=" " )
                    #print('\n' + str(length) + ' ' + str(length+len(word.split())-1) + ' NEG')
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else:
                        tup = tup + tup1        
        if not targ == 0:
            file_pointer.write(tup +'\n')
    #else:
        #print('None')
        
    print('\n\n')
# Out:
# {'Source': [[], []], 'Target': [['personnel'], ['63:72']], 'Polar_expression': [['helpful'], ['55:62']], 'Polarity': 'Positive', 'Intensity': 'Standard'}
# 11 11 POS | {'Source': [[], []], 'Target': [['personnel'], ['63:72']], 'Polar_expression': [['very friendly'], ['37:50']], 'Polarity': 'Positive', 'Intensity': 'Strong'}
# 11 11 POS | {'Source': [[], []], 'Target': [['experience'], ['134:144']], 'Polar_expression': [['really good'], ['122:133']], 'Polarity': 'Positive', 'Intensity': 'Strong'}
# 24 24 POS | {'Source': [[], []], 'Target': [['welcome'], ['10:17']], 'Polar_expression': [['very warm'], ['0:9']], 'Polarity': 'Positive', 'Intensity': 'Strong'}
# 2 2 POS | {'Source': [[], []], 'Target': [['breakfast buffet'], ['288:304']], 'Polar_expression': [['very nicely assorted'], ['267:287']], 'Polarity': 'Positive', 'Intensity': 'Strong'}
# 53 54 POS
#
#
# ...

# %%
file_sent = open('dev.sent', 'w')
file_tup = open('dev.tup', 'w')
file_pointer = open('dev.pointer', 'w')
num = 1
for i in data:
    tup = ""
    pointer = ""
    #print(i['opinions'])
    if i['opinions']:
        targ = 0
        lt = 0
        lo = len(i['opinions'])
        string = i['text']
        #if i['opinions'][0]['Target'][0]:
            
        for j in i['opinions']:
            if j['Target'][0]:
                if targ==0:
                    #print(num)
                    #num = num + 1
                    #print(i['text'])
                    file_sent.write(i['text']+'\n')
                    targ = targ + 1
                    #print(j)
                length = 0
                word = j['Target'][0][0]
                index = string.find(word)
                for i in range(index):
                    if string[i] == " ":
                        length = length + 1 
                if (j['Polarity']=='Positive'):
                    tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS'
                    pointer1 = str(length) + ' ' + str(length+len(word.split())-1) + ' POS'
                    print('\n' + str(length) + ' ' + str(length+len(word.split())-1) + ' POS')
                    print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS',end=" " )
                    
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else :
                        tup = tup + tup1
                elif (j['Polarity']=='Negative'):
                    tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG'
                    pointer1 = str(length) + ' ' + str(length+len(word.split())-1) + ' NEG'
                    print('\n' + str(length) + ' ' + str(length+len(word.split())-1) + ' NEG')
                    print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG',end=" " )
                    
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                        pointer = pointer + pointer1 + " | "
                    else:
                        tup = tup + tup1
                        pointer = pointer + pointer1
                        
                       
                
        if not targ == 0:
            print(pointer)
            file_pointer.write(pointer +'\n')
            file_tup.write(tup +'\n')
    #else:
        #print('None')
        
    print('\n\n')

# %%
l2 = 'very warm welcome at the reception'
word = 'at'    
string = l2.split(" ")
index = string.index(word)
index
# Out:
# 3

# %%
message = 'Python is a fun programming language and also it a language name'

# check the index of 'fun'
print(message.find('a fun'))

# Output: 12
# Out:
# 10

# %%
import numpy as np
if message:
    length = 0
    string = message
    word = 'language name'
    index = string.find(word)
    for i in np.arange(index):
        if string[i] == " ":
            length = length + 1
    print(word + ' ' + str(index) + ' ' + str(length))
# Out:
# language name 51 10

# %%
########################### MAIN CODE ######################################
file_sent = open('dev.sent', 'w')
file_tup = open('dev.tup', 'w')
file_pointer = open('dev.pointer', 'w')
for i in data:
    tup=""
    pointer=""
    #print(i['opinions'])
    if i['opinions']:
        num = 0
        targ = 0
        lt = 0
        lo = len(i['opinions'])
        string = i['text']
        #if i['opinions'][0]['Target'][0]:
            
        for j in i['opinions']:
            if j['Target'][0]:
                num = num + 1
                if targ==0:
                    #print(num)
                    #num = num + 1
                    #print(i['text'])
                    file_sent.write(i['text']+'\n')
                    targ = targ + 1
        #print(j)
                length = 0
                word = j['Target'][0][0]
                index = string.find(word)
                for i in range(index):
                    if string[i] == " ":
                        length = length + 1
                
                if (j['Polarity']=='Positive'):
                    tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS'
                    pointer1 = str(length) + ' ' + str(length+len(word.split())-1) + ' POS'
                    #print(str(length) + ' ' + str(length+len(word.split())-1) + ' POS',end=" " )
                    #print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS',end=" " )
                    lt = lt+1
                    if not lt == lo:
                        #print("|",end = " ")
                        tup = tup + tup1 + " | "
                        pointer = pointer + pointer1 + " | "
                    else :
                        tup = tup + tup1
                        pointer = pointer + pointer1
                elif (j['Polarity']=='Negative'):
                    tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG'
                    pointer1 = str(length) + ' ' + str(length+len(word.split())-1) + ' NEG'
                    #print(str(length) + ' ' + str(length+len(word.split())-1) + ' NEG',end=" " )
                    #print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG',end=" " )
                    lt = lt+1
                    if not lt == lo:
                        #print("|",end = " ")
                        tup = tup + tup1 + " | "
                        pointer = pointer + pointer1 + " | "
                    else :
                        tup = tup + tup1
                        pointer = pointer + pointer1
        if not targ == 0:
            file_tup.write(tup +'\n')
            file_pointer.write(pointer +'\n')
    #else:
        #print('None')
        
    #print('\n\n')

# %%
#file_sent = open('dev.sent', 'w')
#file_tup = open('dev.tup', 'w')
file_pointer = open('dev.pointer', 'w')
for i in data:
    tup=""
    #print(i['opinions'])
    if i['opinions']:
        num = 0
        targ = 0
        lt = 0
        lo = len(i['opinions'])
        string = i['text']
        #if i['opinions'][0]['Target'][0]:
            
        for j in i['opinions']:
            print(j)
            if j['Target'][0]:
                num = num + 1
                if targ==0:
                    #print(num)
                    #num = num + 1
                    #print(i['text'])
                    #file_sent.write(i['text']+'\n')
                    targ = targ + 1
        #print(j)
                length = 0
                word = j['Target'][0][0]
                index = string.find(word)
                for i in range(index):
                    if string[i] == " ":
                        length = length + 1
                
                if (j['Polarity']=='Positive'):
                    tup1 = str(length) + ' ' + str(length+len(word.split())-1) + ' POS'
                    print(str(length) + ' ' + str(length+len(word.split())-1) + ' POS',end=" " )
                    #tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS'
                    #print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; POS',end=" " )
                    #print('\n' + str(length) + ' ' + str(length+len(word.split())-1) + ' POS')
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else :
                        tup = tup + tup1
                elif (j['Polarity']=='Negative'):
                    tup1 = str(length) + ' ' + str(length+len(word.split())-1) + ' NEG'
                    print(str(length) + ' ' + str(length+len(word.split())-1) + ' NEG',end=" " )
                    #tup1 = j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG'
                    #print(j['Target'][0][0] + ' ; ' + j['Polar_expression'][0][0] + ' ; NEG',end=" " )
                    #print('\n' + str(length) + ' ' + str(length+len(word.split())-1) + ' NEG')
                    lt = lt+1
                    if not lt == lo:
                        print("|",end = " ")
                        tup = tup + tup1 + " | "
                    else:
                        tup = tup + tup1        
        if not targ == 0:
            file_pointer.write(tup +'\n')
    #else:
        #print('None')
        
    print('\n\n')
